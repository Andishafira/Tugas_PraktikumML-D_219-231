# %% [markdown]
# <a href="https://colab.research.google.com/github/Andishafira/Tugas_PraktikumML-D_219-231/blob/Fira/TugasML_KelompokV2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #CNN

# %% [markdown]
# # Load Dataset

# %%
#Menyambungkan dataset pada laman Kaggle
#jangan lupa file json
! pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.62.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2021.5.30)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (5.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)

# %%
! mkdir ~/.kaggle

# %%
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets download paultimothymooney/chest-xray-pneumonia
# Out:
# Downloading chest-xray-pneumonia.zip to /content
# 100% 2.29G/2.29G [00:25<00:00, 40.5MB/s]
# 100% 2.29G/2.29G [00:25<00:00, 96.7MB/s]

# %%
#Unzip Data
from zipfile import ZipFile
file_name = "chest-xray-pneumonia.zip"

with ZipFile(file_name,'r') as zip :
  zip.extractall()
  print('Berhasil')
# Out:
# Berhasil

# %% [markdown]
# #Preprocessing

# %%
#Import library yang dibutuhkan
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from keras.models import Sequential
from keras.layers import InputLayer, Dense, Conv2D, MaxPool2D
from keras.layers import Dropout
from keras.layers import GlobalMaxPooling2D, AveragePooling2D, GlobalAveragePooling2D, Flatten
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , BatchNormalization
from tensorflow.keras.optimizers import SGD, Adam
from sklearn.preprocessing import LabelEncoder
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from keras.callbacks import ReduceLROnPlateau
import cv2
import os
import shutil

# %%
#Pengambilan Data
labels = ['PNEUMONIA', 'NORMAL']
img_size = 150
def get_training_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
                resized_arr = cv2.resize(img_arr, (img_size, img_size))
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)

# %% [markdown]
# ###Spliting Data

# %%
# !mkdir /content/chest_xray/chest_xray/allData
# !mkdir /content/chest_xray/chest_xray/allData/NORMAL
# !mkdir /content/chest_xray/chest_xray/allData/PNEUMONIA

# %%
#Inisialisasi Path
train_Normal = '/content/chest_xray/chest_xray/train/NORMAL'
train_Pneumonia = '/content/chest_xray/chest_xray/train/PNEUMONIA'
test_Normal = '/content/chest_xray/chest_xray/test/NORMAL'
test_Pneumonia = '/content/chest_xray/chest_xray/test/PNEUMONIA'
val_Normal = '/content/chest_xray/chest_xray/val/NORMAL'
val_Pneumonia = '/content/chest_xray/chest_xray/val/PNEUMONIA'
allData_Normal = '/content/chest_xray/chest_xray/allData/NORMAL'
allData_Pneumonia = '/content/chest_xray/chest_xray/allData/PNEUMONIA'

# %%
filesTrainN = os.listdir(train_Normal)
filesTrainP = os.listdir(train_Pneumonia)
filesTestN = os.listdir(test_Normal)
filesTestP = os.listdir(test_Pneumonia)

# %%
for file in filesTrainN:
  new_path = shutil.move(f"{train_Normal}/{file}",allData_Normal)

# %%
for file in filesTestN:
  new_path = shutil.move(f"{test_Normal}/{file}",allData_Normal)

# %%
for file in filesTrainP:
  new_path = shutil.move(f"{train_Pneumonia}/{file}",allData_Pneumonia)
for file in filesTestP:
  new_path = shutil.move(f"{test_Pneumonia}/{file}",allData_Pneumonia)

# %%
# !mkdir /content/chest_xray/chest_xray/trainNew
# !mkdir /content/chest_xray/chest_xray/trainNew/NORMAL
# !mkdir /content/chest_xray/chest_xray/trainNew/PNEUMONIA

# !mkdir /content/chest_xray/chest_xray/testNew
# !mkdir /content/chest_xray/chest_xray/testNew/NORMAL
# !mkdir /content/chest_xray/chest_xray/testNew/PNEUMONIA

# !mkdir /content/chest_xray/chest_xray/valNew
# !mkdir /content/chest_xray/chest_xray/valNew/NORMAL
# !mkdir /content/chest_xray/chest_xray/valNew/PNEUMONIA

# %%
train_Normal_new = '/content/chest_xray/chest_xray/trainNew/NORMAL'
train_Pneumonia_new = '/content/chest_xray/chest_xray/trainNew/PNEUMONIA'
test_Normal_new = '/content/chest_xray/chest_xray/testNew/NORMAL'
test_Pneumonia_new = '/content/chest_xray/chest_xray/testNew/PNEUMONIA'
val_Normal_new = '/content/chest_xray/chest_xray/valNew/NORMAL'
val_Pneumonia_new = '/content/chest_xray/chest_xray/valNew/PNEUMONIA'

# %%
files_allData_Normal = os.listdir(allData_Normal)

# %%
for file in files_allData_Normal[0:int(len(files_allData_Normal) * .01)]:
  new_path = shutil.move(f"{allData_Normal}/{file}", test_Normal_new)

# %%
files_allData_Pneumonia = os.listdir(allData_Pneumonia)

# %%
for file in files_allData_Pneumonia[0:int(len(files_allData_Pneumonia) * .01)]:
  new_path = shutil.move(f"{allData_Pneumonia}/{file}", test_Pneumonia_new)

# %%
files_allData_Normal1 = os.listdir(allData_Normal)

for file in files_allData_Normal1:
  new_path = shutil.move(f"{allData_Normal}/{file}", train_Normal_new)

# %%
files_allData_Pneumonia1 = os.listdir(allData_Pneumonia)

for file in files_allData_Pneumonia1:
  new_path = shutil.move(f"{allData_Pneumonia}/{file}", train_Pneumonia_new)

# %%
files_train_Normal = os.listdir(train_Normal_new)

for file in files_train_Normal[0:int(len(files_train_Normal) * .19)]:
  new_path = shutil.copy(f"{train_Normal_new}/{file}", val_Normal_new)

# %%
files_train_Pneumonia = os.listdir(train_Pneumonia_new)

for file in files_train_Pneumonia[0:int(len(files_train_Pneumonia) * .19)]:
  new_path = shutil.copy(f"{train_Pneumonia_new}/{file}", val_Pneumonia_new)

# %%
train = get_training_data('/content/chest_xray/chest_xray/trainNew')
test = get_training_data('/content/chest_xray/chest_xray/testNew')
val = get_training_data('/content/chest_xray/chest_xray/valNew')
# Out:
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   app.launch_new_instance()
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %% [markdown]
# ###Analisis Data

# %%
#Analisis Data
cekData = []
for i in train:
    if(i[1] == 0):
        cekData.append("Pneumonia")
    else:
        cekData.append("Normal")
sns.set_style('darkgrid')
sns.countplot(cekData)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Imbalance Dataset

# %%
#Print sampel data dari masing masing label
fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(15,10), subplot_kw={'xticks':[], 'yticks':[]})

for i, ax in enumerate(axes.flat):
        img = train[i][0]
        ax.imshow(img, cmap='gray')
        ax.set_title("Normal")
fig.tight_layout()    
plt.show()

fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(15,10), subplot_kw={'xticks':[], 'yticks':[]})

for i, ax in enumerate(axes.flat):
        img = train[-(i+1)][0]
        ax.imshow(img, cmap='gray')
        ax.set_title("Pneumonia")
fig.tight_layout()
plt.show()

# %% [markdown]
# # Augmentasi & Normalisasi

# %% [markdown]
# Data Augmentation

# %% [markdown]
# Tujuan :
# 1. Menghindari overfitting
# 2. Handling unbalance dataset
# 3. Menghasilkan model yang konsisten

# %%
#Splitting Data
#X = Fitur
#Y = Label
x_train = []
y_train = []

x_val = []
y_val = []

x_test = []
y_test = []

for feature, label in train:
    x_train.append(feature)
    y_train.append(label)

for feature, label in test:
    x_test.append(feature)
    y_test.append(label)
    
for feature, label in val:
    x_val.append(feature)
    y_val.append(label)

# %%
#Normalisasi Data
#Biar dalam rentang 0-1
x_train = np.array(x_train) / 255 #255 = nilai max
x_val = np.array(x_val) / 255
x_test = np.array(x_test) / 255

# %%
#Resize Data
x_train = x_train.reshape(-1, img_size, img_size, 1)
y_train = np.array(y_train)

x_val = x_val.reshape(-1, img_size, img_size, 1)
y_val = np.array(y_val)

x_test = x_test.reshape(-1, img_size, img_size, 1)
y_test = np.array(y_test)

# %%
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range = 30,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.2, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip = True,  # randomly flip images
        vertical_flip=False)  # randomly flip images


datagen.fit(x_train)

# %%
x_train = np.array(x_train)
x_val = np.array(x_val)
x_test = np.array(x_test)

# %%
lb = LabelEncoder()
y_train = lb.fit_transform(y_train)
y_test = lb.fit_transform(y_test)
print(y_train)
# Out:
# [0 0 0 ... 1 1 1]

# %% [markdown]
# # Modelling

# %% [markdown]
# ## Modelling Scenario 1

# %%
model = Sequential()

model.add(InputLayer(input_shape=[150, 150, 1]))

model.add(Conv2D(filters=16, kernel_size=3, strides=1, padding='same', activation='relu'))
model.add(Dropout(0.2))
model.add(MaxPool2D(pool_size=2, padding='same'))

model.add(Conv2D(filters=32, kernel_size=3, strides=1, padding='same', activation='relu'))
model.add(Dropout(0.2))
model.add(MaxPool2D(pool_size=2, padding='same'))

model.add(Conv2D(filters=64, kernel_size=3, strides=1, padding='same', activation='relu'))
model.add(Dropout(0.2))
model.add(MaxPool2D(pool_size=2, padding='same'))

model.add(GlobalMaxPooling2D())
model.add(Flatten())

model.add(Dense(128, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 16)
100
# 290/290 [==============================] - 7s 25ms/step - loss: 0.0234 - acc: 0.9917 - val_loss: 0.3822 - val_acc: 0.8947
# Epoch 100/100
# 290/290 [==============================] - 7s 25ms/step - loss: 0.0183 - acc: 0.9938 - val_loss: 0.4872 - val_acc: 0.8947

# %% [markdown]
# ## Modelling Scenario 2

# %%
mod = Sequential()

mod.add(InputLayer(input_shape=[150, 150, 1]))
mod.add(Conv2D(filters=16, kernel_size=3, strides=1, padding='same', activation='relu'))
mod.add(Dropout(0.2))
mod.add(AveragePooling2D(pool_size=2, padding='same'))

mod.add(Conv2D(filters=32, kernel_size=3, strides=1, padding='same', activation='relu'))
mod.add(Dropout(0.2))
mod.add(AveragePooling2D(pool_size=2, padding='same'))

mod.add(Conv2D(filters=64, kernel_size=3, strides=1, padding='same', activation='relu'))
mod.add(Dropout(0.2))
mod.add(AveragePooling2D(pool_size=2, padding='same'))

mod.add(GlobalAveragePooling2D())
mod.add(Flatten())

mod.add(Dense(128, activation='relu'))
mod.add(Dense(1, activation='sigmoid'))

# %%
print(mod.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 150, 150, 16)      160
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 150, 150, 16)      0
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 75, 75, 16)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 75, 75, 32)        4640
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 75, 75, 32)        0
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 38, 38, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 38, 38, 64)        18496
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 38, 38, 64)        0
# _________________________________________________________________
# average_pooling2d_2 (Average (None, 19, 19, 64)        0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 64)                0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               8320
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 31,745
# Trainable params: 31,745
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
mod.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['acc'])

# %%
model_2 = mod.fit(x_train, y_train, batch_size=20, epochs=100, validation_data=(x_test, y_test))
# Out:
# Epoch 1/100
# 290/290 [==============================] - 8s 25ms/step - loss: 0.5837 - acc: 0.7283 - val_loss: 0.5359 - val_acc: 0.7368
# Epoch 2/100
# 290/290 [==============================] - 7s 24ms/step - loss: 0.5108 - acc: 0.7296 - val_loss: 0.4496 - val_acc: 0.7368
# Epoch 3/100
# 290/290 [==============================] - 7s 24ms/step - loss: 0.4916 - acc: 0.7301 - val_loss: 0.4296 - val_acc: 0.7368
# Epoch 4/100
# 290/290 [==============================] - 7s 24ms/step - loss: 0.4768 - acc: 0.7370 - val_loss: 0.4192 - val_acc: 0.7368
# Epoch 5/100
# 290/290 [==============================] - 7s 24ms/step - loss: 0.4578 - acc: 0.7643 - val_loss: 0.4012 - val_acc: 0.7544
# Epoch 6/100
# 290/290 [==============================] - 7s 24ms/step - loss: 0.4324 - acc: 0.7901 - val_loss: 0.4000 - val_acc: 0.8246
# Epoch 7/100
# 290/290 [==============================] - 7s 24ms/step - loss: 0.4114 - acc: 0.8129 - val_loss: 0.4319 - val_acc: 0.7368
# Epoch 8/100
# 290/290 [==============================] - 7s 24ms/step - loss: 0.3892 - acc: 0.8209 - val_loss: 0.3326 - val_acc: 0.8246
# Epoch 9/100
# 290/290 [==============================] - 7s 24ms/step - loss: 0.3598 - acc: 0.8399 - val_loss: 0.3330 - val_acc: 0.8421
# Epoch 10/100
# 290/290 [==============================] - 7s 24ms/step - loss: 0.3243 - acc: 0.8575 - val_loss: 0.2753 - val_acc: 0.8772
# Epoch 11/100
# 290/290 [==============================] - 7s 24ms/step - loss: 0.3075 - acc: 0.8682 - val_loss: 0.2641 - val_acc: 0.8772
# Epoch 12/100
# 290/290 [==============================] - 7s 24ms/step - loss: 0.2971 - acc: 0.8717 - val_loss: 0.3260 - val_acc: 0.8070
# Epoch 13/100
# 290/290 [==============================] - 7s 24ms/step - loss: 0.2839 - acc: 0.8755 - val_loss: 0.2633 - val_acc: 0.8947
# Epoch 14/100
# 290/290 [==============================] - 7s 24ms/step - loss: 0.2695 - acc: 0.8866 - val_loss: 0.2270 - val_acc: 0.8947
# Epoch 15/100
# 290/290 [==============================] - 7s 24ms/step - loss: 0.2722 - acc: 0.8890 - val_loss: 0.3174 - val_acc: 0.8246
# Epoch 16/100
# 290/290 [==============================] - 7s 24ms/step - loss: 0.2522 - acc: 0.8918 - val_loss: 0.2521 - val_acc: 0.8596
# Epoch 17/100
# 290/290 [==============================] - 7s 24ms/step - loss: 0.2521 - acc: 0.8957 - val_loss: 0.2160 - val_acc: 0.8947
# Epoch 18/100
# 290/290 [==============================] - 7s 24ms/step - loss: 0.2382 - acc: 0.9061 - val_loss: 0.2772 - val_acc: 0.8772
# Epoch 19/100
# 290/290 [==============================] - 7s 24ms/step - loss: 0.2321 - acc: 0.9064 - val_loss: 0.2280 - val_acc: 0.8947
# Epoch 20/100
# 290/290 [==============================] - 7s 24ms/step - loss: 0.2370 - acc: 0.9030 - val_loss: 0.2364 - val_acc: 0.9123
# Epoch 21/100
# 290/290 [==============================] - 7s 24ms/step - loss: 0.2229 - acc: 0.9125 - val_loss: 0.2005 - val_acc: 0.9123
# Epoch 22/100
# 290/290 [==============================] - 7s 24ms/step - loss: 0.
100
# 290/290 [==============================] - 7s 24ms/step - loss: 0.1157 - acc: 0.9578 - val_loss: 0.1982 - val_acc: 0.8947
# Epoch 91/100
# 290/290 [==============================] - 7s 24ms/step - loss: 0.1075 - acc: 0.9590 - val_loss: 0.2098 - val_acc: 0.9123
# Epoch 92/100
# 290/290 [==============================] - 7s 24ms/step - loss: 0.1158 - acc: 0.9564 - val_loss: 0.2306 - val_acc: 0.9123
# Epoch 93/100
# 290/290 [==============================] - 7s 24ms/step - loss: 0.1065 - acc: 0.9602 - val_loss: 0.1765 - val_acc: 0.8947
# Epoch 94/100
# 290/290 [==============================] - 7s 24ms/step - loss: 0.1033 - acc: 0.9611 - val_loss: 0.1779 - val_acc: 0.8947
# Epoch 95/100
# 290/290 [==============================] - 7s 24ms/step - loss: 0.1075 - acc: 0.9604 - val_loss: 0.1981 - val_acc: 0.9123
# Epoch 96/100
# 290/290 [==============================] - 7s 24ms/step - loss: 0.1060 - acc: 0.9613 - val_loss: 0.2040 - val_acc: 0.8947
# Epoch 97/100
# 290/290 [==============================] - 7s 24ms/step - loss: 0.1001 - acc: 0.9613 - val_loss: 0.2048 - val_acc: 0.8947
# Epoch 98/100
# 290/290 [==============================] - 7s 24ms/step - loss: 0.1019 - acc: 0.9630 - val_loss: 0.2064 - val_acc: 0.8947
# Epoch 99/100
# 290/290 [==============================] - 7s 24ms/step - loss: 0.1049 - acc: 0.9618 - val_loss: 0.2609 - val_acc: 0.8947
# Epoch 100/100
# 290/290 [==============================] - 7s 24ms/step - loss: 0.1042 - acc: 0.9620 - val_loss: 0.1976 - val_acc: 0.8947

# %% [markdown]
# ## Loss & Accuracy Plot

# %%
import matplotlib.pyplot as plt

plt.plot(model_1.history["loss"], label="train_loss_model_1")
plt.plot(model_1.history["val_loss"], label="test_loss_model_1")
plt.plot(model_2.history["loss"], label="train_loss_model_2")
plt.plot(model_2.history["val_loss"], label="val_loss_model_2")
plt.title("Loss Result")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend()
plt.show()

plt.plot(model_1.history["acc"], label="train_acc_model_1")
plt.plot(model_1.history["val_acc"], label="val_acc_model_1")
plt.plot(model_2.history["acc"], label="train_acc_model_2")
plt.plot(model_2.history["val_acc"], label="val_acc_model_2")
plt.title("Accuracy Result")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend()
plt.show()

# %% [markdown]
# ## Saving Model

# %%
base_path = 'model'
project_name = 'all_models'
save_model = 'model_2.h5'
model_path = os.path.join(base_path, project_name, save_model)

if os.path.exists(os.path.join(base_path, project_name)) == False:
  os.makedirs(os.path.join(base_path, project_name))

mod.save(save_model, include_optimizer=False)
print('Model has been saved!')
# Out:
# Model has been saved!

# %% [markdown]
# ## Modelling Scenario 3

# %%
model3 = Sequential()
model3.add(Conv2D(32 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu' , input_shape = (150,150,1)))
model3.add(BatchNormalization())
model3.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

model3.add(Conv2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model3.add(Dropout(0.1))
model3.add(BatchNormalization())
model3.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

model3.add(Conv2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model3.add(BatchNormalization())
model3.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

model3.add(Conv2D(128 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model3.add(Dropout(0.15))
model3.add(BatchNormalization())
model3.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

model3.add(Conv2D(256 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model3.add(Dropout(0.2))
model3.add(BatchNormalization())
model3.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

model3.add(Flatten())
model3.add(Dense(units = 128 , activation = 'relu'))
model3.add(Dropout(0.2))

model3.add(Dense(units = 1 , activation = 'sigmoid'))
model3.compile(optimizer = "adam" , loss = 'binary_crossentropy' , metrics = ['accuracy'])
model3.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 32)      320
# _________________________________________________________________
# batch_normalization (BatchNo (None, 150, 150, 32)      128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 75, 75, 64)        18496
# _________________________________________________________________
# dropout (Dropout)            (None, 75, 75, 64)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 75, 75, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 38, 38, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 38, 38, 64)        36928
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 38, 38, 64)        256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 19, 19, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 19, 19, 128)       73856
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 19, 19, 128)       0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 19, 19, 128)       512
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 10, 10, 256)       295168
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 10, 10, 256)       0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 10, 10, 256)       1024
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 5, 5, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6400)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               819328
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 1,246,401
# Trainable params: 1,245,313
# Non-trainable params: 1,088
# _________________________________________________________________

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience = 2, verbose=1,factor=0.3, min_lr=0.000001)
model_3 = model3.fit(datagen.flow(x_train,y_train, batch_size = 32) ,epochs = 100 , validation_data = datagen.flow(x_val, y_val) ,callbacks = [learning_rate_reduction])
# Out:
# Epoch 1/100
# 181/181 [==============================] - 51s 111ms/step - loss: 0.3486 - accuracy: 0.8701 - val_loss: 3.7820 - val_accuracy: 0.7308
# Epoch 2/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.2261 - accuracy: 0.9132 - val_loss: 1.2116 - val_accuracy: 0.7308
# Epoch 3/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.2037 - accuracy: 0.9231 - val_loss: 0.2440 - val_accuracy: 0.9115
# Epoch 4/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.1871 - accuracy: 0.9334 - val_loss: 0.2716 - val_accuracy: 0.9015
# Epoch 5/100
# 181/181 [==============================] - 19s 105ms/step - loss: 0.1707 - accuracy: 0.9364 - val_loss: 1.0657 - val_accuracy: 0.5985
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# Epoch
100
# 181/181 [==============================] - 19s 107ms/step - loss: 0.1080 - accuracy: 0.9604 - val_loss: 0.1078 - val_accuracy: 0.9644
# Epoch 99/100
# 181/181 [==============================] - 19s 107ms/step - loss: 0.1071 - accuracy: 0.9630 - val_loss: 0.1129 - val_accuracy: 0.9562
# Epoch 100/100
# 181/181 [==============================] - 19s 107ms/step - loss: 0.1067 - accuracy: 0.9620 - val_loss: 0.1048 - val_accuracy: 0.9608

# %%
from sklearn.metrics import classification_report

pred = model3.predict(x_val)
labels = (pred > 0.5).astype(np.int)

print(classification_report(y_val, labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.90      0.94       801
#            1       0.79      0.97      0.87       295
#
#     accuracy                           0.92      1096
#    macro avg       0.89      0.94      0.91      1096
# weighted avg       0.93      0.92      0.92      1096

# %% [markdown]
# ## Modelling Scenario 4

# %%
model4 = Sequential()
model4.add(Conv2D(32 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu' , input_shape = (150,150,1)))
model4.add(BatchNormalization())
model4.add(AveragePooling2D((2,2) , strides = 2 , padding = 'same'))

model4.add(Conv2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model4.add(Dropout(0.1))
model4.add(BatchNormalization())
model4.add(AveragePooling2D((2,2) , strides = 2 , padding = 'same'))

model4.add(Conv2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model4.add(BatchNormalization())
model4.add(AveragePooling2D((2,2) , strides = 2 , padding = 'same'))

model4.add(Conv2D(128 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model4.add(Dropout(0.15))
model4.add(BatchNormalization())
model4.add(AveragePooling2D((2,2) , strides = 2 , padding = 'same'))

model4.add(Conv2D(256 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model4.add(Dropout(0.2))
model4.add(BatchNormalization())
model4.add(AveragePooling2D((2,2) , strides = 2 , padding = 'same'))

model4.add(Flatten())
model4.add(Dense(units = 128 , activation = 'relu'))
model4.add(Dropout(0.2))

model4.add(Dense(units = 1 , activation = 'sigmoid'))
model4.compile(optimizer = "adam" , loss = 'binary_crossentropy' , metrics = ['accuracy'])
model4.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 150, 150, 32)      320
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 150, 150, 32)      128
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 75, 75, 64)        18496
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 75, 75, 64)        0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 75, 75, 64)        256
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 38, 38, 64)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 38, 38, 64)        36928
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 38, 38, 64)        256
# _________________________________________________________________
# average_pooling2d_2 (Average (None, 19, 19, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 19, 19, 128)       73856
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 19, 19, 128)       0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 19, 19, 128)       512
# _________________________________________________________________
# average_pooling2d_3 (Average (None, 10, 10, 128)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 10, 10, 256)       295168
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 10, 10, 256)       0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 10, 10, 256)       1024
# _________________________________________________________________
# average_pooling2d_4 (Average (None, 5, 5, 256)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 6400)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               819328
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 1,246,401
# Trainable params: 1,245,313
# Non-trainable params: 1,088
# _________________________________________________________________

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience = 2, verbose=1,factor=0.3, min_lr=0.000001)
model_4 = model4.fit(datagen.flow(x_train,y_train, batch_size = 32) ,epochs = 100 , validation_data = datagen.flow(x_val, y_val) ,callbacks = [learning_rate_reduction])
# Out:
# Epoch 1/100
# 181/181 [==============================] - 21s 107ms/step - loss: 0.3138 - accuracy: 0.8720 - val_loss: 0.8075 - val_accuracy: 0.7308
# Epoch 2/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.2535 - accuracy: 0.9009 - val_loss: 0.8095 - val_accuracy: 0.6797
# Epoch 3/100
# 181/181 [==============================] - 19s 105ms/step - loss: 0.2224 - accuracy: 0.9144 - val_loss: 0.3772 - val_accuracy: 0.8130
# Epoch 4/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.2050 - accuracy: 0.9236 - val_loss: 0.6397 - val_accuracy: 0.7609
# Epoch 5/100
# 181/181 [==============================] - 19s 105ms/step - loss: 0.1996 - accuracy: 0.9196 - val_loss: 3.3493 - val_accuracy: 0.7308
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# Epoch 6/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.1716 - accuracy: 0.9381 - val_loss: 0.7819 - val_accuracy: 0.6560
# Epoch 7/100
# 181/181 [==============================] - 19s 105ms/step - loss: 0.1544 - accuracy: 0.9405 - val_loss: 0.2411 - val_accuracy: 0.8987
# Epoch 8/100
# 181/181 [==============================] - 19s 105ms/step - loss: 0.1407 - accuracy: 0.9478 - val_loss: 0.1585 - val_accuracy: 0.9434
# Epoch 9/100
# 181/181 [==============================] - 19s 105ms/step - loss: 0.1482 - accuracy: 0.9471 - val_loss: 1.9704 - val_accuracy: 0.5265
# Epoch 10/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.1448 - accuracy: 0.9464 - val_loss: 0.2624 - val_accuracy: 0.9015
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# Epoch 11/100
# 181/181 [==============================] - 19s 105ms/step - loss: 0.1278 - accuracy: 0.9552 - val_loss: 0.1205 - val_accuracy: 0.9562
# Epoch 12/100
# 181/181 [==============================] - 19s 105ms/step - loss: 0.1194 - accuracy: 0.9543 - val_loss: 0.1245 - val_accuracy: 0.9589
# Epoch 13/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.1274 - accuracy: 0.9535 - val_loss: 0.2527 - val_accuracy: 0.9024
# Epoch 14/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.1160 - accuracy: 0.9597 - val_loss: 0.1119 - val_accuracy: 0.9562
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# Epoch 15/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.1127 - accuracy: 0.9609 - val_loss: 0.1471 - val_accuracy: 0.9453
# Epoch 16/100
# 181/181 [==============================] - 19s 105ms/step - loss: 0.1133 - accuracy: 0.9599 - val_loss: 0.1015 - val_accuracy: 0.9644
# Epoch 17/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.1115 - accuracy: 0.9616 - val_loss: 0.0980 - val_accuracy: 0.9608
# Epoch 18/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.1087 - accuracy: 0.9614 - val_loss: 0.1001 - val_accuracy: 0.9644
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# Epoch 19/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.1093 - accuracy: 0.9609 - val_loss: 0.0941 - val_accuracy: 0.9690
# Epoch 20/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.1060 - accuracy: 0.9602 - val_loss: 0.1034 - val_accuracy: 0.9599
# Epoch 21/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.1071 - accuracy: 0.9602 - val_loss: 0.1052 - val_accuracy: 0.9562
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# Epoch 22/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.1103 - accuracy: 0.9613 - val_loss: 0.0960 - val_accuracy: 0.9681
# Epoch 23/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.1035 - accuracy: 0.9647 - val_loss: 0.0972 - val_accuracy: 0.9653
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 1e-06.
# Epoch 24/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.1046 - accuracy: 0.9623 - val_loss: 0.0962 - val_accuracy: 0.9653
# Epoch 25/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.0995 - accuracy: 0.9607 - val_loss: 0.0987 - val_accuracy: 0.9617
# Epoch 26/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.1054 - accuracy: 0.9633 - val_loss: 0.0986 - val_accuracy: 0.9617
# Epoch 27/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.1048 - accuracy: 0.9611 - val_loss: 0.0979 - val_accuracy: 0.9626
# Epoch 28/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.1073 - accuracy: 0.9637 - val_loss: 0.0970 - val_accuracy: 0.9599
# Epoch 29/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.1120 - accuracy: 0.9563 - val_loss: 0.0981 - val_accuracy: 0.9653
# Epoch 30/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.1039 - accuracy: 0.9647 - val_loss: 0.0976 - val_accuracy: 0.9562
# Epoch 31/100
# 181/181 [==============================] - 19s 107ms/step - loss: 0.1032 - accuracy: 0.9614 - val_loss: 0.0962 - val_accuracy: 0.9644
# Epoch 32/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.1035 - accuracy: 0.9640 - val_loss: 0.1002 - val_accuracy: 0.9626
# Epoch 33/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.1098 - accuracy: 0.9578 - val_loss: 0.1073 - val_accuracy: 0.9644
# Epoch 34/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.1057 - accuracy: 0.9616 - val_loss: 0.0966 - val_accuracy: 0.9690
# Epoch 35/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.1024 - accuracy: 0.9628 - val_loss: 0.0988 - val_accuracy: 0.9635
# Epoch 36/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.1110 - accuracy: 0.9595 - val_loss: 0.0997 - val_accuracy: 0.9589
# Epoch 37/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.1039 - accuracy: 0.9623 - val_loss: 0.0947 - val_accuracy: 0.9644
# Epoch 38/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.0991 - accuracy: 0.9661 - val_loss: 0.0934 - val_accuracy: 0.9653
# Epoch 39/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.1050 - accuracy: 0.9630 - val_loss: 0.0966 - val_accuracy: 0.9626
# Epoch 40/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.1073 - accuracy: 0.9609 - val_loss: 0.1052 - val_accuracy: 0.9617
# Epoch 41/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.1086 - accuracy: 0.9604 - val_loss: 0.0857 - val_accuracy: 0.9672
# Epoch 42/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.1053 - accuracy: 0.9611 - val_loss: 0.0866 - val_accuracy: 0.9726
# Epoch 43/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.1051 - accuracy: 0.9623 - val_loss: 0.1069 - val_accuracy: 0.9599
# Epoch 44/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.1053 - accuracy: 0.9614 - val_loss: 0.1076 - val_accuracy: 0.9617
# Epoch 45/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.1081 - accuracy: 0.9606 - val_loss: 0.0935 - val_accuracy: 0.9653
# Epoch 46/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.1032 - accuracy: 0.9613 - val_loss: 0.0880 - val_accuracy: 0.9672
# Epoch 47/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.1058 - accuracy: 0.9616 - val_loss: 0.0975 - val_accuracy: 0.9580
# Epoch 48/100
# 181/181 [==============================] - 19s 105ms/step - loss: 0.1069 - accuracy: 0.9609 - val_loss: 0.1019 - val_accuracy: 0.9626
# Epoch 49/100
# 181/181 [==============================] - 19s 105ms/step - loss: 0.1089 - accuracy: 0.9630 - val_loss: 0.1005 - val_accuracy: 0.9617
# Epoch 50/100
# 181/181 [==============================] - 19s 105ms/step - loss: 0.1049 - accuracy: 0.9639 - val_loss: 0.1079 - val_accuracy: 0.9617
# Epoch 51/100
# 181/181 [==============================] - 19s 105ms/step - loss: 0.1002 - accuracy: 0.9637 - val_loss: 0.0968 - val_accuracy: 0.9644
# Epoch 52/100
# 181/181 [==============================] - 19s 105ms/step - loss: 0.1013 - accuracy: 0.9626 - val_loss: 0.0975 - val_accuracy: 0.9653
# Epoch 53/100
# 181/181 [==============================] - 19s 105ms/step - loss: 0.1001 - accuracy: 0.9637 - val_loss: 0.0940 - val_accuracy: 0.9626
# Epoch 54/100
# 181/181 [==============================] - 19s 105ms/step - loss: 0.1069 - accuracy: 0.9621 - val_loss: 0.0943 - val_accuracy: 0.9681
# Epoch 55/100
# 181/181 [==============================] - 19s 105ms/step - loss: 0.1064 - accuracy: 0.9601 - val_loss: 0.0877 - val_accuracy: 0.9653
# Epoch 56/100
# 181/181 [==============================] - 19s 105ms/step - loss: 0.1108 - accuracy: 0.9609 - val_loss: 0.0883 - val_accuracy: 0.9672
# Epoch 57/100
# 181/181 [==============================] - 19s 105ms/step - loss: 0.1062 - accuracy: 0.9592 - val_loss: 0.0828 - val_accuracy: 0.9717
# Epoch 58/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.1053 - accuracy: 0.9614 - val_loss: 0.1081 - val_accuracy: 0.9599
# Epoch 59/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.1110 - accuracy: 0.9632 - val_loss: 0.0975 - val_accuracy: 0.9626
# Epoch 60/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.1082 - accuracy: 0.9623 - val_loss: 0.1068 - val_accuracy: 0.9580
# Epoch 61/100
# 181/181 [==============================] - 19s 107ms/step - loss: 0.1037 - accuracy: 0.9613 - val_loss: 0.0967 - val_accuracy: 0.9672
# Epoch 62/100
# 181/181 [==============================] - 19s 107ms/step - loss: 0.1025 - accuracy: 0.9606 - val_loss: 0.0974 - val_accuracy: 0.9662
# Epoch 63/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.1044 - accuracy: 0.9618 - val_loss: 0.1023 - val_accuracy: 0.9635
# Epoch 64/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.1118 - accuracy: 0.9590 - val_loss: 0.1033 - val_accuracy: 0.9644
# Epoch 65/100
# 181/181 [==============================] - 19s 105ms/step - loss: 0.1080 - accuracy: 0.9595 - val_loss: 0.0965 - val_accuracy: 0.9608
# Epoch 66/100
# 181/181 [==============================] - 19s 105ms/step - loss: 0.1028 - accuracy: 0.9618 - val_loss: 0.1027 - val_accuracy: 0.9599
# Epoch 67/100
# 181/181 [==============================] - 19s 105ms/step - loss: 0.1033 - accuracy: 0.9625 - val_loss: 0.0912 - val_accuracy: 0.9735
# Epoch 68/100
# 181/181 [==============================] - 19s 105ms/step - loss: 0.1062 - accuracy: 0.9637 - val_loss: 0.1008 - val_accuracy: 0.9644
# Epoch 69/100
# 181/181 [==============================] - 19s 105ms/step - loss: 0.1038 - accuracy: 0.9632 - val_loss: 0.0954 - val_accuracy: 0.9653
# Epoch 70/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.1091 - accuracy: 0.9597 - val_loss: 0.0975 - val_accuracy: 0.9626
# Epoch 71/100
# 181/181 [==============================] - 19s 105ms/step - loss: 0.0963 - accuracy: 0.9661 - val_loss: 0.0982 - val_accuracy: 0.9653
# Epoch 72/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.1040 - accuracy: 0.9613 - val_loss: 0.1143 - val_accuracy: 0.9599
# Epoch 73/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.1038 - accuracy: 0.9644 - val_loss: 0.0963 - val_accuracy: 0.9672
# Epoch 74/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.1064 - accuracy: 0.9623 - val_loss: 0.0971 - val_accuracy: 0.9608
# Epoch 75/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.0984 - accuracy: 0.9651 - val_loss: 0.0961 - val_accuracy: 0.9653
# Epoch 76/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.1037 - accuracy: 0.9613 - val_loss: 0.0921 - val_accuracy: 0.9681
# Epoch 77/100
# 181/181 [==============================] - 19s 105ms/step - loss: 0.1071 - accuracy: 0.9625 - val_loss: 0.0973 - val_accuracy: 0.9608
# Epoch 78/100
# 181/181 [==============================] - 19s 105ms/step - loss: 0.1073 - accuracy: 0.9599 - val_loss: 0.0877 - val_accuracy: 0.9681
# Epoch 79/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.1029 - accuracy: 0.9621 - val_loss: 0.0877 - val_accuracy: 0.9644
# Epoch 80/100
# 181/181 [==============================] - 19s 105ms/step - loss: 0.1047 - accuracy: 0.9623 - val_loss: 0.0956 - val_accuracy: 0.9672
# Epoch 81/100
# 181/181 [==============================] - 19s 105ms/step - loss: 0.1045 - accuracy: 0.9637 - val_loss: 0.0977 - val_accuracy: 0.9653
# Epoch 82/100
# 181/181 [==============================] - 19s 105ms/step - loss: 0.1052 - accuracy: 0.9606 - val_loss: 0.1071 - val_accuracy: 0.9589
# Epoch 83/100
# 181/181 [==============================] - 19s 105ms/step - loss: 0.0988 - accuracy: 0.9659 - val_loss: 0.0923 - val_accuracy: 0.9635
# Epoch 84/100
# 181/181 [==============================] - 19s 105ms/step - loss: 0.1018 - accuracy: 0.9623 - val_loss: 0.0981 - val_accuracy: 0.9644
# Epoch 85/100
# 181/181 [==============================] - 19s 105ms/step - loss: 0.1014 - accuracy: 0.9640 - val_loss: 0.1034 - val_accuracy: 0.9626
# Epoch 86/100
# 181/181 [==============================] - 19s 105ms/step - loss: 0.1045 - accuracy: 0.9633 - val_loss: 0.1053 - val_accuracy: 0.9635
# Epoch 87/100
# 181/181 [==============================] - 19s 105ms/step - loss: 0.1116 - accuracy: 0.9618 - val_loss: 0.0980 - val_accuracy: 0.9635
# Epoch 88/100
# 181/181 [==============================] - 19s 105ms/step - loss: 0.1049 - accuracy: 0.9607 - val_loss: 0.1050 - val_accuracy: 0.9608
# Epoch 89/100
# 181/181 [==============================] - 19s 105ms/step - loss: 0.1052 - accuracy: 0.9633 - val_loss: 0.1023 - val_accuracy: 0.9635
# Epoch 90/100
# 181/181 [==============================] - 19s 105ms/step - loss: 0.1058 - accuracy: 0.9618 - val_loss: 0.0993 - val_accuracy: 0.9608
# Epoch 91/100
# 181/181 [==============================] - 19s 105ms/step - loss: 0.1072 - accuracy: 0.9606 - val_loss: 0.0941 - val_accuracy: 0.9644
# Epoch 92/100
# 181/181 [==============================] - 19s 105ms/step - loss: 0.1114 - accuracy: 0.9602 - val_loss: 0.0931 - val_accuracy: 0.9617
# Epoch 93/100
# 181/181 [==============================] - 19s 105ms/step - loss: 0.1002 - accuracy: 0.9639 - val_loss: 0.0956 - val_accuracy: 0.9662
# Epoch 94/100
# 181/181 [==============================] - 19s 105ms/step - loss: 0.1065 - accuracy: 0.9620 - val_loss: 0.1010 - val_accuracy: 0.9635
# Epoch 95/100
# 181/181 [==============================] - 19s 105ms/step - loss: 0.1027 - accuracy: 0.9604 - val_loss: 0.1065 - val_accuracy: 0.9599
# Epoch 96/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.1022 - accuracy: 0.9625 - val_loss: 0.0901 - val_accuracy: 0.9681
# Epoch 97/100
# 181/181 [==============================] - 19s 105ms/step - loss: 0.1032 - accuracy: 0.9630 - val_loss: 0.0946 - val_accuracy: 0.9626
# Epoch 98/100
# 181/181 [==============================] - 19s 106ms/step - loss: 0.1060 - accuracy: 0.9613 - val_loss: 0.0931 - val_accuracy: 0.9626
# Epoch 99/100
# 181/181 [==============================] - 19s 105ms/step - loss: 0.1047 - accuracy: 0.9630 - val_loss: 0.0954 - val_accuracy: 0.9644
# Epoch 100/100
# 181/181 [==============================] - 19s 105ms/step - loss: 0.1027 - accuracy: 0.9635 - val_loss: 0.0834 - val_accuracy: 0.9754

# %%
from sklearn.metrics import classification_report

pred = model4.predict(x_val)
labels = (pred > 0.5).astype(np.int)

print(classification_report(y_val, labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.95      0.97       801
#            1       0.87      0.95      0.91       295
#
#     accuracy                           0.95      1096
#    macro avg       0.93      0.95      0.94      1096
# weighted avg       0.95      0.95      0.95      1096

# %% [markdown]
# #Loss & Accuracy Plot

# %%
import matplotlib.pyplot as plt

plt.plot(model_3.history["loss"], label="train_loss_model_3")
plt.plot(model_3.history["val_loss"], label="test_loss_model_3")
plt.plot(model_4.history["loss"], label="train_loss_model_4")
plt.plot(model_4.history["val_loss"], label="val_loss_model_4")
plt.title("Loss Result")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend()
plt.show()

plt.plot(model_3.history["accuracy"], label="train_acc_model_3")
plt.plot(model_3.history["accuracy"], label="val_acc_model_3")
plt.plot(model_4.history["accuracy"], label="train_acc_model_4")
plt.plot(model_4.history["accuracy"], label="val_acc_model_4")
plt.title("Accuracy Result")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend()
plt.show()

# %% [markdown]
# #Saving Model 3 and 4

# %%
model3.save_weights('model_3_weights.h5')
model4.save_weights('model_4_weights.h5')

# %%
model3.save('model_3.h5')
model4.save('model_4.h5')
