# %% [markdown]
# <a href="https://colab.research.google.com/github/Andishafira/Tugas_PraktikumML-D_219-231/blob/Fira/TugasML_KelompokV3_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = "/content/drive/MyDrive/TugasBesar_MachineLearning"

# %%
# %cd /content/drive/MyDrive/TugasBesar_MachineLearning
# Out:
# /content/drive/MyDrive/TugasBesar_MachineLearning

# %%
# !ls
# Out:
#  chest_xray	   'person1661_virus_2873 (1).jpeg'
#  first_model.json  'person1661_virus_2873 (2).jpeg'
#  kaggle.json	   'person1661_virus_2873 (3).jpeg'
#  model_6.h5	   'person1661_virus_2873 (4).jpeg'
#  model_deploy.h5    person1661_virus_2873.jpeg
#  model.png

# %%
#Import library yang dibutuhkan
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from tensorflow.keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import InputLayer, Dense, Conv2D, MaxPool2D
from tensorflow.keras.layers import Dropout, SpatialDropout2D
from keras.layers import GlobalMaxPooling2D, AveragePooling2D, GlobalAveragePooling2D, Flatten
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , BatchNormalization
from tensorflow.keras.optimizers import SGD, Adam
from sklearn.preprocessing import LabelEncoder
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from keras.callbacks import ReduceLROnPlateau
import cv2
import os
import shutil

# %%
#Pengambilan Data
labels = ['PNEUMONIA', 'NORMAL']
img_size = 150
def get_training_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
                resized_arr = cv2.resize(img_arr, (img_size, img_size))
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)

# %%
# !pip install split-folders
# Out:
# Collecting split-folders
#   Downloading split_folders-0.4.3-py3-none-any.whl (7.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.4.3

# %%
mainFolder="/content/drive/MyDrive/TugasBesar_MachineLearning/chest_xray"
dataFolder="/content/drive/MyDrive/TugasBesar_MachineLearning/chest_xray/chest_xray/allData"

# %%
import splitfolders
#splitfolders.ratio(dataFolder, output=mainFolder, seed=1337, ratio=(.7,.1,.2),group_prefix=None)

# %%
train = get_training_data('/content/drive/MyDrive/TugasBesar_MachineLearning/chest_xray/train')
test = get_training_data('/content/drive/MyDrive/TugasBesar_MachineLearning/chest_xray/test')
val = get_training_data('/content/drive/MyDrive/TugasBesar_MachineLearning/chest_xray/val')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   app.launch_new_instance()

# %%
#Analisis Data
cekData = []
for i in train:
    if(i[1] == 0):
        cekData.append("Pneumonia")
    else:
        cekData.append("Normal")
sns.set_style('darkgrid')
sns.countplot(cekData)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Print sampel data dari masing masing label
fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(15,10), subplot_kw={'xticks':[], 'yticks':[]})

for i, ax in enumerate(axes.flat):
        img = train[i][0]
        ax.imshow(img, cmap='gray')
        ax.set_title("Normal")
fig.tight_layout()    
plt.show()

fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(15,10), subplot_kw={'xticks':[], 'yticks':[]})

for i, ax in enumerate(axes.flat):
        img = train[-(i+1)][0]
        ax.imshow(img, cmap='gray')
        ax.set_title("Pneumonia")
fig.tight_layout()
plt.show()

# %%
#Splitting Data
#X = Fitur
#Y = Label
x_train = []
y_train = []

x_val = []
y_val = []

x_test = []
y_test = []

for feature, label in train:
    x_train.append(feature)
    y_train.append(label)

for feature, label in test:
    x_test.append(feature)
    y_test.append(label)
    
for feature, label in val:
    x_val.append(feature)
    y_val.append(label)

# %%
#Normalisasi Data
#Biar dalam rentang 0-1
x_train = np.array(x_train) / 255 #255 = nilai max
x_val = np.array(x_val) / 255
x_test = np.array(x_test) / 255

# %%
#Resize Data
x_train = x_train.reshape(-1, img_size, img_size, 1)
y_train = np.array(y_train)

x_val = x_val.reshape(-1, img_size, img_size, 1)
y_val = np.array(y_val)

x_test = x_test.reshape(-1, img_size, img_size, 1)
y_test = np.array(y_test)

# %%
datagen = ImageDataGenerator(
        featurewise_center=False,  # set rata rata input menjadi 0 di atas dataset
        samplewise_center=False,  # set setiap rata rata sampel menjadi 0
        featurewise_std_normalization=False,  # membagi input dengan std dari dataset
        samplewise_std_normalization=False,  # bagi setiap input dengan std
        zca_whitening=False,  # ZCA whitening
        rotation_range = 30,  # melakukan rotate gambar secara acak dalam rentang derajat 0 -180
        zoom_range = 0.2, # melakukan zoom gambar secara acak 
        width_shift_range=0.1,  # menggeser gambar secara acak secara horizontal
        height_shift_range=0.1,  # menggeser gambar secara acak secara vertikal
        horizontal_flip = True,  # membalik gambar horizontal secara acak
        vertical_flip=False)  # melakukan membalik gambar vertikal secara acak

# %%
x_train = np.array(x_train)
x_val = np.array(x_val)
x_test = np.array(x_test)

# %%
lb = LabelEncoder()
y_train = lb.fit_transform(y_train)
y_test = lb.fit_transform(y_test)
print(y_train)
# Out:
# [0 0 0 ... 1 1 1]

# %%
model3 = Sequential()
model3.add(Conv2D(32 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu' , input_shape = (150,150,1)))
model3.add(BatchNormalization())
model3.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

model3.add(Conv2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model3.add(Dropout(0.1))
model3.add(BatchNormalization())
model3.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

model3.add(Conv2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model3.add(BatchNormalization())
model3.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

model3.add(Conv2D(128 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model3.add(Dropout(0.15))
model3.add(BatchNormalization())
model3.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

model3.add(Conv2D(256 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model3.add(Dropout(0.2))
model3.add(BatchNormalization())
model3.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

model3.add(Flatten())
model3.add(Dense(units = 128 , activation = 'relu'))
model3.add(Dropout(0.2))

model3.add(Dense(units = 1 , activation = 'sigmoid'))
model3.compile(optimizer = "adam" , loss = 'binary_crossentropy' , metrics = ['accuracy'])
model3.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 150, 150, 32)      320
#
#  batch_normalization (BatchN  (None, 150, 150, 32)     128
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 75, 75, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 75, 75, 64)        18496
#
#  dropout (Dropout)           (None, 75, 75, 64)        0
#
#  batch_normalization_1 (Batc  (None, 75, 75, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 38, 38, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 38, 38, 64)        36928
#
#  batch_normalization_2 (Batc  (None, 38, 38, 64)       256
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 19, 19, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 19, 19, 128)       73856
#
#  dropout_1 (Dropout)         (None, 19, 19, 128)       0
#
#  batch_normalization_3 (Batc  (None, 19, 19, 128)      512
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 10, 10, 128)      0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 10, 10, 256)       295168
#
#  dropout_2 (Dropout)         (None, 10, 10, 256)       0
#
#  batch_normalization_4 (Batc  (None, 10, 10, 256)      1024
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 5, 5, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 6400)              0
#
#  dense (Dense)               (None, 128)               819328
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 1,246,401
# Trainable params: 1,245,313
# Non-trainable params: 1,088
# _________________________________________________________________

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience = 2, verbose=1,factor=0.3, min_lr=0.000001)
model_3 = model3.fit(datagen.flow(x_train,y_train, batch_size = 32) ,epochs = 100 , validation_data = datagen.flow(x_val, y_val) ,callbacks = [learning_rate_reduction])
# Out:
# Epoch 1/100
# 61/61 [==============================] - 21s 125ms/step - loss: 0.7647 - accuracy: 0.7888 - val_loss: 5.4560 - val_accuracy: 0.7307 - lr: 0.0010
# Epoch 2/100
# 61/61 [==============================] - 7s 110ms/step - loss: 0.3108 - accuracy: 0.8748 - val_loss: 6.2130 - val_accuracy: 0.7307 - lr: 0.0010
# Epoch 3/100
# 61/61 [==============================] - ETA: 0s - loss: 0.2711 - accuracy: 0.8928
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 61/61 [==============================] - 7s 112ms/step - loss: 0.2711 - accuracy: 0.8928 - val_loss: 6.6996 - val_accuracy: 0.7307 - lr: 0.0010
# Epoch 4/100
# 61/61 [==============================] - 7s 113ms/step - loss: 0.2560 - accuracy: 0.9067 - val_loss: 6.3143 - val_accuracy: 0.7307 - lr: 3.0000e-04
# Epoch 5/100
# 61/61 [==============================] - ETA: 0s - loss: 0.2340 - accuracy: 0.9140
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 61/61 [==============================] - 7s 114ms/step - loss: 0.2340 - accuracy: 0.9140 - val_loss: 7.2123 - val_accuracy: 0.7307 - lr: 3.0000e-04
# Epoch 6/100
# 61/61 [==============================] - 7s 116ms/step - loss: 0.2221 - accuracy: 0.9129 - val_loss: 6.4299 - val_accuracy: 0.7307 - lr: 9.0000e-05
# Epoch 7/100
# 61/61 [==============================] - ETA: 0s - loss: 0.2220 - accuracy: 0.9207
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 61/61 [==============================] - 7s 114ms/step - loss: 0.2220 - accuracy: 0.9207 - val_loss: 4.8862 - val_accuracy: 0.7307 - lr: 9.0000e-05
# Epoch 8/100
# 61/61 [==============================] - 7s 114ms/step - loss: 0.2199 - accuracy: 0.9171 - val_loss: 3.9808 - val_accuracy: 0.7307 - lr: 2.7000e-05
# Epoch 9/100
# 61/61 [==============================] - ETA: 0s - loss: 0.2270 - accuracy: 0.9171
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# 61/61 [==============================] - 7s 114ms/step - loss: 0.2270 - accuracy: 0.9171 - val_loss: 2.7370 - val_accuracy: 0.7307 - lr: 2.7000e-05
# Epoch 10/100
# 61/61 [==============================] - 7s 114ms/step - loss: 0.2134 - accuracy: 0.9212 - val_loss: 1.6866 - val_accuracy: 0.7358 - lr: 8.1000e-06
# Epoch 11/100
# 61/61 [==============================] - 7s 114ms/step - loss: 0.2114 - accuracy: 0.9191 - val_loss: 0.8245 - val_accuracy: 0.7925 - lr: 8.1000e-06
# Epoch 12/100
100
# 61/61 [==============================] - 7s 109ms/step - loss: 0.2070 - accuracy: 0.9212 - val_loss: 0.2089 - val_accuracy: 0.9417 - lr: 1.0000e-06
# Epoch 79/100
# 61/61 [==============================] - 7s 109ms/step - loss: 0.1965 - accuracy: 0.9243 - val_loss: 0.1989 - val_accuracy: 0.9348 - lr: 1.0000e-06
# Epoch 80/100
# 61/61 [==============================] - 7s 110ms/step - loss: 0.1996 - accuracy: 0.9253 - val_loss: 0.2051 - val_accuracy: 0.9451 - lr: 1.0000e-06
# Epoch 81/100
# 61/61 [==============================] - 7s 110ms/step - loss: 0.1929 - accuracy: 0.9227 - val_loss: 0.1849 - val_accuracy: 0.9468 - lr: 1.0000e-06
# Epoch 82/100
# 61/61 [==============================] - 7s 109ms/step - loss: 0.2070 - accuracy: 0.9279 - val_loss: 0.2185 - val_accuracy: 0.9383 - lr: 1.0000e-06
# Epoch 83/100
# 61/61 [==============================] - 7s 109ms/step - loss: 0.2038 - accuracy: 0.9284 - val_loss: 0.2078 - val_accuracy: 0.9383 - lr: 1.0000e-06
# Epoch 84/100
# 61/61 [==============================] - 7s 109ms/step - loss: 0.2058 - accuracy: 0.9227 - val_loss: 0.2146 - val_accuracy: 0.9417 - lr: 1.0000e-06
# Epoch 85/100
# 61/61 [==============================] - 7s 109ms/step - loss: 0.2012 - accuracy: 0.9268 - val_loss: 0.2122 - val_accuracy: 0.9348 - lr: 1.0000e-06
# Epoch 86/100
# 61/61 [==============================] - 7s 110ms/step - loss: 0.1878 - accuracy: 0.9279 - val_loss: 0.2191 - val_accuracy: 0.9485 - lr: 1.0000e-06
# Epoch 87/100
# 61/61 [==============================] - 7s 108ms/step - loss: 0.1944 - accuracy: 0.9243 - val_loss: 0.2095 - val_accuracy: 0.9383 - lr: 1.0000e-06
# Epoch 88/100
# 61/61 [==============================] - 7s 109ms/step - loss: 0.1900 - accuracy: 0.9284 - val_loss: 0.1983 - val_accuracy: 0.9365 - lr: 1.0000e-06
# Epoch 89/100
# 61/61 [==============================] - 7s 107ms/step - loss: 0.2007 - accuracy: 0.9304 - val_loss: 0.2185 - val_accuracy: 0.9348 - lr: 1.0000e-06
# Epoch 90/100
# 61/61 [==============================] - 7s 110ms/step - loss: 0.2028 - accuracy: 0.9299 - val_loss: 0.1920 - val_accuracy: 0.9434 - lr: 1.0000e-06
# Epoch 91/100
# 61/61 [==============================] - 7s 109ms/step - loss: 0.1941 - accuracy: 0.9279 - val_loss: 0.1971 - val_accuracy: 0.9365 - lr: 1.0000e-06
# Epoch 92/100
# 61/61 [==============================] - 7s 108ms/step - loss: 0.1941 - accuracy: 0.9232 - val_loss: 0.2017 - val_accuracy: 0.9417 - lr: 1.0000e-06
# Epoch 93/100
# 61/61 [==============================] - 7s 108ms/step - loss: 0.1960 - accuracy: 0.9268 - val_loss: 0.2010 - val_accuracy: 0.9417 - lr: 1.0000e-06
# Epoch 94/100
# 61/61 [==============================] - 7s 108ms/step - loss: 0.2108 - accuracy: 0.9227 - val_loss: 0.2125 - val_accuracy: 0.9417 - lr: 1.0000e-06
# Epoch 95/100
# 61/61 [==============================] - 7s 109ms/step - loss: 0.2040 - accuracy: 0.9243 - val_loss: 0.2061 - val_accuracy: 0.9348 - lr: 1.0000e-06
# Epoch 96/100
# 61/61 [==============================] - 7s 109ms/step - loss: 0.2004 - accuracy: 0.9289 - val_loss: 0.2182 - val_accuracy: 0.9314 - lr: 1.0000e-06
# Epoch 97/100
# 61/61 [==============================] - 7s 108ms/step - loss: 0.2061 - accuracy: 0.9238 - val_loss: 0.1968 - val_accuracy: 0.9417 - lr: 1.0000e-06
# Epoch 98/100
# 61/61 [==============================] - 7s 108ms/step - loss: 0.2087 - accuracy: 0.9274 - val_loss: 0.2202 - val_accuracy: 0.9451 - lr: 1.0000e-06
# Epoch 99/100
# 61/61 [==============================] - 7s 113ms/step - loss: 0.1982 - accuracy: 0.9263 - val_loss: 0.1970 - val_accuracy: 0.9485 - lr: 1.0000e-06
# Epoch 100/100
# 61/61 [==============================] - 7s 108ms/step - loss: 0.2056 - accuracy: 0.9217 - val_loss: 0.2051 - val_accuracy: 0.9365 - lr: 1.0000e-06

# %%
from sklearn.metrics import classification_report

pred = model3.predict(x_test)
labels = (pred > 0.5).astype(np.int)

print(classification_report(y_test, labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.89      0.93       854
#            1       0.76      0.96      0.85       316
#
#     accuracy                           0.91      1170
#    macro avg       0.87      0.93      0.89      1170
# weighted avg       0.92      0.91      0.91      1170

# %%
from tensorflow.keras.preprocessing.image import load_img
from keras.preprocessing import image
from google.colab import files

# %%
model4 = Sequential()
model4.add(Conv2D(32 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu' , input_shape = (150,150,1)))
model4.add(BatchNormalization())
model4.add(AveragePooling2D((2,2) , strides = 2 , padding = 'same'))

model4.add(Conv2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model4.add(Dropout(0.1))
model4.add(BatchNormalization())
model4.add(AveragePooling2D((2,2) , strides = 2 , padding = 'same'))

model4.add(Conv2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model4.add(BatchNormalization())
model4.add(AveragePooling2D((2,2) , strides = 2 , padding = 'same'))

model4.add(Conv2D(128 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model4.add(Dropout(0.15))
model4.add(BatchNormalization())
model4.add(AveragePooling2D((2,2) , strides = 2 , padding = 'same'))

model4.add(Conv2D(256 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model4.add(Dropout(0.2))
model4.add(BatchNormalization())
model4.add(AveragePooling2D((2,2) , strides = 2 , padding = 'same'))

model4.add(Flatten())
model4.add(Dense(units = 128 , activation = 'relu'))
model4.add(Dropout(0.2))

model4.add(Dense(units = 1 , activation = 'sigmoid'))
model4.compile(optimizer = "adam" , loss = 'binary_crossentropy' , metrics = ['accuracy'])
model4.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 150, 150, 32)      320
#
#  batch_normalization_5 (Batc  (None, 150, 150, 32)     128
#  hNormalization)
#
#  average_pooling2d (AverageP  (None, 75, 75, 32)       0
#  ooling2D)
#
#  conv2d_6 (Conv2D)           (None, 75, 75, 64)        18496
#
#  dropout_4 (Dropout)         (None, 75, 75, 64)        0
#
#  batch_normalization_6 (Batc  (None, 75, 75, 64)       256
#  hNormalization)
#
#  average_pooling2d_1 (Averag  (None, 38, 38, 64)       0
#  ePooling2D)
#
#  conv2d_7 (Conv2D)           (None, 38, 38, 64)        36928
#
#  batch_normalization_7 (Batc  (None, 38, 38, 64)       256
#  hNormalization)
#
#  average_pooling2d_2 (Averag  (None, 19, 19, 64)       0
#  ePooling2D)
#
#  conv2d_8 (Conv2D)           (None, 19, 19, 128)       73856
#
#  dropout_5 (Dropout)         (None, 19, 19, 128)       0
#
#  batch_normalization_8 (Batc  (None, 19, 19, 128)      512
#  hNormalization)
#
#  average_pooling2d_3 (Averag  (None, 10, 10, 128)      0
#  ePooling2D)
#
#  conv2d_9 (Conv2D)           (None, 10, 10, 256)       295168
#
#  dropout_6 (Dropout)         (None, 10, 10, 256)       0
#
#  batch_normalization_9 (Batc  (None, 10, 10, 256)      1024
#  hNormalization)
#
#  average_pooling2d_4 (Averag  (None, 5, 5, 256)        0
#  ePooling2D)
#
#  flatten_1 (Flatten)         (None, 6400)              0
#
#  dense_2 (Dense)             (None, 128)               819328
#
#  dropout_7 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 1,246,401
# Trainable params: 1,245,313
# Non-trainable params: 1,088
# _________________________________________________________________

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience = 2, verbose=1,factor=0.3, min_lr=0.000001)
model_4 = model4.fit(datagen.flow(x_train,y_train, batch_size = 32) ,epochs = 100 , validation_data = datagen.flow(x_val, y_val) ,callbacks = [learning_rate_reduction])
# Out:
# Epoch 1/100
# 61/61 [==============================] - 8s 111ms/step - loss: 0.5005 - accuracy: 0.8058 - val_loss: 1.3604 - val_accuracy: 0.2693 - lr: 0.0010
# Epoch 2/100
# 61/61 [==============================] - 6s 106ms/step - loss: 0.3520 - accuracy: 0.8604 - val_loss: 5.1385 - val_accuracy: 0.2693 - lr: 0.0010
# Epoch 3/100
# 61/61 [==============================] - ETA: 0s - loss: 0.3022 - accuracy: 0.8861
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 61/61 [==============================] - 6s 105ms/step - loss: 0.3022 - accuracy: 0.8861 - val_loss: 5.8447 - val_accuracy: 0.2693 - lr: 0.0010
# Epoch 4/100
# 61/61 [==============================] - 6s 106ms/step - loss: 0.2595 - accuracy: 0.9001 - val_loss: 1.3395 - val_accuracy: 0.2967 - lr: 3.0000e-04
# Epoch 5/100
# 61/61 [==============================] - 7s 109ms/step - loss: 0.2349 - accuracy: 0.9109 - val_loss: 1.0612 - val_accuracy: 0.4614 - lr: 3.0000e-04
# Epoch 6/100
# 61/61 [==============================] - 7s 111ms/step - loss: 0.2408 - accuracy: 0.9088 - val_loss: 0.7452 - val_accuracy: 0.6346 - lr: 3.0000e-04
# Epoch 7/100
# 61/61 [==============================] - 7s 110ms/step - loss: 0.2279 - accuracy: 0.9150 - val_loss: 0.6831 - val_accuracy: 0.7581 - lr: 3.0000e-04
# Epoch 8/100
# 61/61 [==============================] - 7s 109ms/step - loss: 0.2324 - accuracy: 0.9067 - val_loss: 1.0575 - val_accuracy: 0.5334 - lr: 3.0000e-04
# Epoch 9/100
# 61/61 [==============================] - 7s 107ms/step - loss: 0.2242 - accuracy: 0.9129 - val_loss: 0.5370 - val_accuracy: 0.8096 - lr: 3.0000e-04
# Epoch 10/100
# 61/61 [==============================] - 7s 110ms/step - loss: 0.2163 - accuracy: 0.9155 - val_loss: 1.8774 - val_accuracy: 0.7393 - lr: 3.0000e-04
# Epoch 11/100
# 61/61 [==============================] - ETA: 0s - loss: 0.2169 - accuracy: 0.9181
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 61/61 [==============================] - 7s 107ms/step - loss: 0.2169 - accuracy: 0.9181 - val_loss: 4.5366 - val_accuracy: 0.3636 - lr: 3.0000e-04
# Epoch 12/100
# 61/61 [==============================] - 7s 108ms/step - loss: 0.1912 - accuracy: 0.9279 - val_loss: 0.2145 - val_accuracy: 0.9142 - lr: 9.0000e-05
# Epoch 13/100
# 61/61 [==============================] - 7s 107ms/step - loss: 0.1988 - accuracy: 0.9248 - val_loss: 0.3232 - val_accuracy: 0.8919 - lr: 9.0000e-05
# Epoch 14/100
# 61/61 [==============================] - 7s 109ms/step - loss: 0.1794 - accuracy: 0.9284 - val_loss: 0.1630 - val_accuracy: 0.9451 - lr: 9.0000e-05
# Epoch 15/100
# 61/61 [==============================] - 7s 109ms/step - loss: 0.
100
# 61/61 [==============================] - 7s 108ms/step - loss: 0.1600 - accuracy: 0.9361 - val_loss: 0.1562 - val_accuracy: 0.9537 - lr: 1.0000e-06
# Epoch 91/100
# 61/61 [==============================] - 7s 108ms/step - loss: 0.1800 - accuracy: 0.9279 - val_loss: 0.1660 - val_accuracy: 0.9348 - lr: 1.0000e-06
# Epoch 92/100
# 61/61 [==============================] - 7s 109ms/step - loss: 0.1700 - accuracy: 0.9351 - val_loss: 0.1664 - val_accuracy: 0.9434 - lr: 1.0000e-06
# Epoch 93/100
# 61/61 [==============================] - 7s 109ms/step - loss: 0.1747 - accuracy: 0.9289 - val_loss: 0.1651 - val_accuracy: 0.9383 - lr: 1.0000e-06
# Epoch 94/100
# 61/61 [==============================] - 7s 109ms/step - loss: 0.1655 - accuracy: 0.9387 - val_loss: 0.1724 - val_accuracy: 0.9468 - lr: 1.0000e-06
# Epoch 95/100
# 61/61 [==============================] - 7s 109ms/step - loss: 0.1695 - accuracy: 0.9366 - val_loss: 0.1694 - val_accuracy: 0.9451 - lr: 1.0000e-06
# Epoch 96/100
# 61/61 [==============================] - 7s 109ms/step - loss: 0.1641 - accuracy: 0.9351 - val_loss: 0.1655 - val_accuracy: 0.9451 - lr: 1.0000e-06
# Epoch 97/100
# 61/61 [==============================] - 7s 110ms/step - loss: 0.1571 - accuracy: 0.9392 - val_loss: 0.1641 - val_accuracy: 0.9537 - lr: 1.0000e-06
# Epoch 98/100
# 61/61 [==============================] - 7s 111ms/step - loss: 0.1587 - accuracy: 0.9320 - val_loss: 0.1713 - val_accuracy: 0.9451 - lr: 1.0000e-06
# Epoch 99/100
# 61/61 [==============================] - 7s 110ms/step - loss: 0.1758 - accuracy: 0.9289 - val_loss: 0.1529 - val_accuracy: 0.9400 - lr: 1.0000e-06
# Epoch 100/100
# 61/61 [==============================] - 7s 112ms/step - loss: 0.1601 - accuracy: 0.9387 - val_loss: 0.1469 - val_accuracy: 0.9485 - lr: 1.0000e-06

# %%
from sklearn.metrics import classification_report

pred = model4.predict(x_test)
labels = (pred > 0.5).astype(np.int)

print(classification_report(y_test, labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.87      0.93       854
#            1       0.74      0.98      0.85       316
#
#     accuracy                           0.90      1170
#    macro avg       0.87      0.93      0.89      1170
# weighted avg       0.92      0.90      0.91      1170

# %%
import matplotlib.pyplot as plt

plt.plot(model_3.history["loss"], label="train_loss_model_3")
plt.plot(model_3.history["val_loss"], label="test_loss_model_3")
plt.plot(model_4.history["loss"], label="train_loss_model_4")
plt.plot(model_4.history["val_loss"], label="val_loss_model_4")
plt.title("Loss Result")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend()
plt.show()

plt.plot(model_3.history["accuracy"], label="train_acc_model_3")
plt.plot(model_3.history["val_accuracy"], label="val_acc_model_3")
plt.plot(model_4.history["accuracy"], label="train_acc_model_4")
plt.plot(model_4.history["val_accuracy"], label="val_acc_model_4")
plt.title("Accuracy Result")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend()
plt.show()

# %%
import json

# %%
save_dir = '/content/drive/MyDrive/TugasBesar_MachineLearning'

json.dump(model3.history, open(save_dir + '/model-newsplit_3.json', 'w'))
model3.save(save_dir + '/model-newsplit_3.h5')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-242f675387a8> in <module>()
#       1 save_dir = '/content/drive/MyDrive/TugasBesar_MachineLearning'
#       2
# ----> 3 json.dump(model3.history, open(save_dir + '/model-newsplit_3.json', 'w'))
#       4 model3.save(save_dir + '/model-newsplit_3.h5')
#
# /usr/lib/python3.7/json/__init__.py in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     177     # could accelerate with writelines in some versions of Python, at
#     178     # a debuggability cost
# --> 179     for chunk in iterable:
#     180         fp.write(chunk)
#     181
#
# /usr/lib/python3.7/json/encoder.py in _iterencode(o, _current_indent_level)
#     436                     raise ValueError("Circular reference detected")
#     437                 markers[markerid] = o
# --> 438             o = _default(o)
#     439             yield from _iterencode(o, _current_indent_level)
#     440             if markers is not None:
#
# /usr/lib/python3.7/json/encoder.py in default(self, o)
#     177
#     178         """
# --> 179         raise TypeError(f'Object of type {o.__class__.__name__} '
#     180                         f'is not JSON serializable')
#     181
#
# TypeError: Object of type History is not JSON serializable

# %%
save_dir = '/content/drive/MyDrive/TugasBesar_MachineLearning'

#json.dump(model_3.history, open(save_dir + '/model-newsplit_3.json', 'w'))
model4.save(save_dir + '/model-newsplit_3.h5')
